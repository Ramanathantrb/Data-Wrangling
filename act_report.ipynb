# %% [markdown]
# ## Report: act_report
# * Create a **250-word-minimum written report** called "act_report.pdf" or "act_report.html" that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %% [markdown]
# ### Insights:
# Popular Dog Breeds: The analysis reveals that "Golden Retriever" is the most commonly predicted dog breed, followed by "Labrador Retriever." This information indicates that these breeds are frequently shared on WeRateDogs.
#
# High Probability Predictions: There are 761 entries where the total calculated probability of being correct is greater than 95%. These predictions are highly reliable and represent cases where the algorithm is very confident about the dog's breed.
#
# Common Dog Stage: The pie chart illustrates that the most common dog life stage in the dataset is "pupper," representing the largest share of the pie.
#
# ### Visualization:
# The visualization is depicted through a histogram that shows the distribution of total probabilities of dog breed predictions. The data is divided into 20 bins between 0 and 1. This graph helps understand the certainty of breed predictions.
#
# Additionally, a pie chart visualizes the distribution of dog life stages, with "pupper" being the dominant category, as confirmed by the data.
#
# These insights and visualizations provide valuable information about the most common dog breeds, the reliability of predictions, and the prevalence of different dog life stages in the WeRateDogs dataset.

# %% [markdown]
# ### Golden Retriever is the most commonly predicted followed by labrador retriever

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import Image
df_merged = pd.read_csv('twitter_archive_master.csv')

# %% [markdown]
# ### A sample image from one of the many tweets

# %%
Image(url='https://pbs.twimg.com/media/DELC9dZXUAADqUk.jpg')
# Out:
# <img src="https://pbs.twimg.com/media/DELC9dZXUAADqUk.jpg"/>

# %% [markdown]
# ### Visualization

# %%
df_merged.stage.value_counts().plot(kind='pie', startangle=90, figsize=(8,8), title="Distribution of Stages", labels=df_merged.stage.value_counts().index)
plt.legend()

# %% [markdown]
# ### Of all the dog life stage available, most of the dogs are in the pupper zone

# %%
bins=np.linspace(0,1,20)
df_merged.total_probability.plot(kind='hist',bins=bins)
plt.xlabel('Total Probability')
plt.ylabel('Frequency')
plt.title('Histogram of Total Probability')
# Out:
# Text(0.5,1,'Histogram of Total Probability')

# %% [markdown]
# ### There are 761 entries where the total calculated probability of being correct is greater than 95%
